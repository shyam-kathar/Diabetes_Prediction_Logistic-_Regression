# %% [markdown]
# import of all the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# Missing Values In Data

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.head(10)
#need to do the data imputation because there is 0's present in some feature
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# ***Exploratory Data Analysis***

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(12,12))
ax= sns.heatmap(df.corr() ,annot=True)
plt.show()

# %% [markdown]
# Descriptive Statistics of given data

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Data Imputation

# %%
sns.distplot(df.Pregnancies)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\3462734468.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Pregnancies)
# <Axes: xlabel='Pregnancies', ylabel='Density'>

# %%
sns.distplot(df.Glucose)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\2035962260.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Glucose)
# <Axes: xlabel='Glucose', ylabel='Density'>

# %%
sns.distplot(df.BloodPressure)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\3755031075.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.BloodPressure)
# <Axes: xlabel='BloodPressure', ylabel='Density'>

# %%
sns.distplot(df.SkinThickness)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\1815010915.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.SkinThickness)
# <Axes: xlabel='SkinThickness', ylabel='Density'>

# %%
sns.distplot(df.Insulin)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\2622307985.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Insulin)
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
sns.distplot(df.BMI)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\1689980233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.BMI)
# <Axes: xlabel='BMI', ylabel='Density'>

# %%
sns.distplot(df.DiabetesPedigreeFunction)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\2655324800.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.DiabetesPedigreeFunction)
# <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %%
sns.distplot(df.Age)
# Out:
# C:\Users\shyam\AppData\Local\Temp\ipykernel_16112\1239919984.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Age)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df["Pregnancies"] = df["Pregnancies"].replace(0 , df["Pregnancies"].median())

# %%
df["Glucose"] = df["Glucose"].replace(0 , df["Glucose"].mean())
df["BloodPressure"] = df["BloodPressure"].replace(0 , df["BloodPressure"].mean())
df["SkinThickness"] = df["SkinThickness"].replace(0 , df["SkinThickness"].median())
df["Insulin"] = df["Insulin"].replace(0 , df["Insulin"].median())
df["Insulin"] = df["Insulin"].replace(0 , df["Insulin"].median())
df["BMI"] = df["BMI"].replace(0 , df["BMI"].mean())
df["DiabetesPedigreeFunction"] = df["DiabetesPedigreeFunction"].replace(0 , df["DiabetesPedigreeFunction"].median())
df["Age"] = df["Age"].replace(0 , df["Age"].median())

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0             6    148.0      72.000000             35     30.5  33.600000
# 1             1     85.0      66.000000             29     30.5  26.600000
# 2             8    183.0      64.000000             23     30.5  23.300000
# 3             1     89.0      66.000000             23     94.0  28.100000
# 4             3    137.0      40.000000             35    168.0  43.100000
# 5             5    116.0      74.000000             23     30.5  25.600000
# 6             3     78.0      50.000000             32     88.0  31.000000
# 7            10    115.0      69.105469             23     30.5  35.300000
# 8             2    197.0      70.000000             45    543.0  30.500000
# 9             8    125.0      96.000000             23     30.5  31.992578
# 10            4    110.0      92.000000             23     30.5  37.600000
# ...

# %% [markdown]
# Outlier Detection

# %%
X  = df.drop(columns="Outcome", axis=1)
y = df['Outcome']

# %%
fig , ax = plt.subplots(figsize =(15,15))
sns.boxplot(data= X ,ax =ax)
plt.tight_layout()
plt.show()

# %%
X.shape
# Out:
# (768, 8)

# %%
coloum = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age'] 
for i in coloum:
    Q1 = X[i].quantile(0.25)
    Q3 = X[i].quantile(0.75)
    IQR = Q3 -Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR
    mask = (X[i] >= lower_bound) & (X[i] <=upper_bound)

# %%
X_OutlierDetection = X[mask]
y_OutlierDetection =y[mask]

# %%
X_OutlierDetection.shape
# Out:
# (759, 8)

# %% [markdown]
# Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_OutlierDetection)

# %%
fig , ax = plt.subplots(figsize =(15,15))
sns.boxplot(data= X_scaled ,ax =ax)
plt.tight_layout()
plt.show()
